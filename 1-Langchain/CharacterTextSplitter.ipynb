# %%
## Text Loader

from langchain_community.document_loaders import TextLoader

loader = TextLoader('File.txt')
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'File.txt'}, page_content='A sample text file for checking langchain document loader\nA sample text file for checking langchain document loaderA sample text file for checking langchain document loaderA sample text file for checking langchain document loaderA sample text file for checking langchain document loaderA sample text file for checking langchain document loaderA sample text file for checking langchain document loader\n\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\n\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\n\n\nv\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nv\nv\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nv\nv\nv\nv\n')]

# %%
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(separator='\n\n' , chunk_size=100 , chunk_overlap=20)
text_splitter.split_documents(docs)
# Out:
# Created a chunk of size 400, which is longer than the specified 100
# Created a chunk of size 289, which is longer than the specified 100
# Created a chunk of size 173, which is longer than the specified 100
# [Document(metadata={'source': 'File.txt'}, page_content='A sample text file for checking langchain document loader\nA sample text file for checking langchain document loaderA sample text file for checking langchain document loaderA sample text file for checking langchain document loaderA sample text file for checking langchain document loaderA sample text file for checking langchain document loaderA sample text file for checking langchain document loader'),
#  Document(metadata={'source': 'File.txt'}, page_content='A sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader'),
#  Document(metadata={'source': 'File.txt'}, page_content='A sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader'),
#  Document(metadata={'source': 'File.txt'}, page_content='v\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nv\nv\nA sample text file for checking langchain document loader\nA sample text file for checking langchain document loader\nv\nv\nv\nv')]
