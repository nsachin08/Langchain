# %%
# Setup LangChain , LangSmith and LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPEN_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.environ["OPENAI_API_KEY"] = os.getenv("OPEN_API_KEY")
#
# File <frozen os>:721, in _Environ.__setitem__(self, key, value)
#     719 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen os>:781, in _createenviron.<locals>.check_str(value)
#     779 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: str expected, not NoneType

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")
llm

# %%
result = llm.invoke("What is generatice AI")
print(result)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
    ("system", "You are an expert AI engineer ."),
    ("user","{input}")
    ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI engineer .'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt|llm

response = chain.invoke({"input": "Can you tell the weather today"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 chain = prompt|llm
#       2
#       3 response = chain.invoke({"input": "Can you tell the weather today"})
#
# NameError: name 'llm' is not defined

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()
chain = prompt|llm|output_parser

response = chain.invoke({"input":"Can you tell the weather today ?"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 from langchain_core.output_parsers import StrOutputParser
#       2
#       3 output_parser = StrOutputParser()
# ----> 4 chain = prompt|llm|output_parser
#
# NameError: name 'llm' is not defined
